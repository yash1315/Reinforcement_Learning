# %% [markdown]
# # Monte Carlo Methods
#
# In this notebook, you will write your own implementations of many Monte Carlo (MC) algorithms.
#
# While we have provided some starter code, you are welcome to erase these hints and write your code from scratch.
#
# ### Part 0: Explore BlackjackEnv
#
# We begin by importing the necessary packages.

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

def plot_blackjack_values(V):

    def get_Z(x, y, usable_ace):
        if (x,y,usable_ace) in V:
            return V[x,y,usable_ace]
        else:
            return 0

    def get_figure(usable_ace, ax):
        x_range = np.arange(11, 22)
        y_range = np.arange(1, 11)
        X, Y = np.meshgrid(x_range, y_range)
        
        Z = np.array([get_Z(x,y,usable_ace) for x,y in zip(np.ravel(X), np.ravel(Y))]).reshape(X.shape)

        surf = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.cm.coolwarm, vmin=-1.0, vmax=1.0)
        ax.set_xlabel('Player\'s Current Sum')
        ax.set_ylabel('Dealer\'s Showing Card')
        ax.set_zlabel('State Value')
        ax.view_init(ax.elev, -120)

    fig = plt.figure(figsize=(20, 20))
    ax = fig.add_subplot(211, projection='3d')
    ax.set_title('Usable Ace')
    get_figure(True, ax)
    ax = fig.add_subplot(212, projection='3d')
    ax.set_title('No Usable Ace')
    get_figure(False, ax)
    plt.show()

def plot_policy(policy):

    def get_Z(x, y, usable_ace):
        if (x,y,usable_ace) in policy:
            return policy[x,y,usable_ace]
        else:
            return 1

    def get_figure(usable_ace, ax):
        x_range = np.arange(11, 22)
        y_range = np.arange(10, 0, -1)
        X, Y = np.meshgrid(x_range, y_range)
        Z = np.array([[get_Z(x,y,usable_ace) for x in x_range] for y in y_range])
        surf = ax.imshow(Z, cmap=plt.get_cmap('Pastel2', 2), vmin=0, vmax=1, extent=[10.5, 21.5, 0.5, 10.5])
        plt.xticks(x_range)
        plt.yticks(y_range)
        plt.gca().invert_yaxis()
        ax.set_xlabel('Player\'s Current Sum')
        ax.set_ylabel('Dealer\'s Showing Card')
        ax.grid(color='w', linestyle='-', linewidth=1)
        divider = make_axes_locatable(ax)
        cax = divider.append_axes("right", size="5%", pad=0.1)
        cbar = plt.colorbar(surf, ticks=[0,1], cax=cax)
        cbar.ax.set_yticklabels(['0 (STICK)','1 (HIT)'])
            
    fig = plt.figure(figsize=(15, 15))
    ax = fig.add_subplot(121)
    ax.set_title('Usable Ace')
    get_figure(True, ax)
    ax = fig.add_subplot(122)
    ax.set_title('No Usable Ace')
    get_figure(False, ax)
    plt.show()

# %%
import sys
import gym
import numpy as np
from collections import defaultdict

#from plot_utils import plot_blackjack_values, plot_policy

# %% [markdown]
# Use the code cell below to create an instance of the [Blackjack](https://github.com/openai/gym/blob/master/gym/envs/toy_text/blackjack.py) environment.

# %%
env = gym.make('Blackjack-v0')

# %% [markdown]
# Each state is a 3-tuple of:
# - the player's current sum $\in \{0, 1, \ldots, 31\}$,
# - the dealer's face up card $\in \{1, \ldots, 10\}$, and
# - whether or not the player has a usable ace (`no` $=0$, `yes` $=1$).
#
# The agent has two potential actions:
#
# ```
#     STICK = 0
#     HIT = 1
# ```
# Verify this by running the code cell below.

# %%
print(env.observation_space.sample)
print(env.action_space.n)
# Out:
# <bound method Tuple.sample of Tuple(Discrete(32), Discrete(11), Discrete(2))>
# 2

# %%
env.step(env.action_space.sample())
# Out:
# ((13, 1, False), -1.0, True, {})

# %% [markdown]
# Execute the code cell below to play Blackjack with a random policy.
#
# (_The code currently plays Blackjack three times - feel free to change this number, or to run the cell multiple times.  The cell is designed for you to get some experience with the output that is returned as the agent interacts with the environment._)

# %%
for i_episode in range(5):
    state = env.reset()
    while True:
        print(state)
        action = env.action_space.sample()
        state, reward, done, info = env.step(action)
        if done:
            print('End game! Reward: ', reward)
            print('You won :)\n') if reward > 0 else print('You lost :(\n')
            break
# Out:
# (13, 10, False)
# (14, 10, False)
# End game! Reward:  -1.0
# You lost :(
#
# (17, 8, False)
# End game! Reward:  -1.0
# You lost :(
#
# (21, 10, True)
# End game! Reward:  0.0
# You lost :(
#
# (17, 2, False)
# End game! Reward:  -1.0
# You lost :(
#
# (6, 6, False)
# (9, 6, False)
# End game! Reward:  1.0
# You won :)

# %% [markdown]
# ### Part 1: MC Prediction
#
# In this section, you will write your own implementation of MC prediction (for estimating the action-value function).
#
# We will begin by investigating a policy where the player _almost_ always sticks if the sum of her cards exceeds 18.  In particular, she selects action `STICK` with 80% probability if the sum is greater than 18; and, if the sum is 18 or below, she selects action `HIT` with 80% probability.  The function `generate_episode_from_limit_stochastic` samples an episode using this policy.
#
# The function accepts as **input**:
# - `bj_env`: This is an instance of OpenAI Gym's Blackjack environment.
#
# It returns as **output**:
# - `episode`: This is a list of (state, action, reward) tuples (of tuples) and corresponds to $(S_0, A_0, R_1, \ldots, S_{T-1}, A_{T-1}, R_{T})$, where $T$ is the final time step.  In particular, `episode[i]` returns $(S_i, A_i, R_{i+1})$, and `episode[i][0]`, `episode[i][1]`, and `episode[i][2]` return $S_i$, $A_i$, and $R_{i+1}$, respectively.

# %%
probs = [0.8, 0.2] if state[0] > 18 else [0.2, 0.8]
action = np.random.choice(np.arange(2), p=probs)
action
# Out:
# 0

# %%
def generate_episode_from_limit_stochastic(bj_env):
    episode = []
    state = bj_env.reset()
    while True:
        probs = [0.8, 0.2] if state[0] > 18 else [0.2, 0.8]
        action = np.random.choice(np.arange(2), p=probs)
        next_state, reward, done, info = bj_env.step(action)
        episode.append((state, action, reward))
        state = next_state
        if done:
            break
    return episode

# %% [markdown]
# Execute the code cell below to play Blackjack with the policy.
#
# (*The code currently plays Blackjack three times - feel free to change this number, or to run the cell multiple times.  The cell is designed for you to gain some familiarity with the output of the `generate_episode_from_limit_stochastic` function.*)

# %%
for i in range(3):
    print(generate_episode_from_limit_stochastic(env))
# Out:
# [((18, 6, True), 1, 0.0), ((17, 6, False), 1, 0.0), ((19, 6, False), 0, 1.0)]
# [((18, 1, False), 1, 0.0), ((19, 1, False), 0, 0.0)]
# [((13, 9, False), 1, 0.0), ((17, 9, False), 1, 0.0), ((21, 9, False), 0, 1.0)]

# %% [markdown]
# Now, you are ready to write your own implementation of MC prediction.  Feel free to implement either first-visit or every-visit MC prediction; in the case of the Blackjack environment, the techniques are equivalent.
#
# Your algorithm has three arguments:
# - `env`: This is an instance of an OpenAI Gym environment.
# - `num_episodes`: This is the number of episodes that are generated through agent-environment interaction.
# - `generate_episode`: This is a function that returns an episode of interaction.
# - `gamma`: This is the discount rate.  It must be a value between 0 and 1, inclusive (default value: `1`).
#
# The algorithm returns as output:
# - `Q`: This is a dictionary (of one-dimensional arrays) where `Q[s][a]` is the estimated action value corresponding to state `s` and action `a`.

# %%
def mc_prediction_q(env, num_episodes, generate_episode, gamma=1.0):
    # initialize empty dictionaries of arrays
    returns_sum = defaultdict(lambda: np.zeros(env.action_space.n))
    N = defaultdict(lambda: np.zeros(env.action_space.n))
    Q = defaultdict(lambda: np.zeros(env.action_space.n))
    # loop over episodes
    for i_episode in range(1, num_episodes+1):
        # monitor progress
        if i_episode % 1000 == 0:
            print("\rEpisode {}/{}.".format(i_episode, num_episodes), end="")
            sys.stdout.flush()
        ## TODO: complete the function
        episode = generate_episode(env)
        # obtain the states, actions, and rewards
        states, actions, rewards = zip(*episode)
        # prepare for discounting
        discounts = np.array([gamma**i for i in range(len(rewards)+1)])
        # update the sum of the returns, number of visits, and action-value 
        # function estimates for each state-action pair in the episode
        for i, state in enumerate(states):
            returns_sum[state][actions[i]] += sum(rewards[i:]*discounts[:-(1+i)])
            N[state][actions[i]] += 1.0
            Q[state][actions[i]] = returns_sum[state][actions[i]] / N[state][actions[i]]
    print("N {} \n, Q {}\n reward_sum {}".format(N,Q,returns_sum ))
    return Q

# %% [markdown]
# Use the cell below to obtain the action-value function estimate $Q$.  We have also plotted the corresponding state-value function.
#
# To check the accuracy of your implementation, compare the plot below to the corresponding plot in the solutions notebook **Monte_Carlo_Solution.ipynb**.

# %%
# obtain the action-value function
Q = mc_prediction_q(env, 5000, generate_episode_from_limit_stochastic)

# obtain the corresponding state-value function
V_to_plot = dict((k,(k[0]>18)*(np.dot([0.8, 0.2],v)) + (k[0]<=18)*(np.dot([0.2, 0.8],v))) \
         for k, v in Q.items())

# plot the state-value function
plot_blackjack_values(V_to_plot)
# Out:
# Episode 5000/5000.N defaultdict(<function mc_prediction_q.<locals>.<lambda> at 0x0000028E7AF409D8>, {(16, 8, False): array([13., 34.]), (18, 7, False): array([ 9., 48.]), (13, 4, False): array([ 8., 24.]), (20, 9, False): array([52., 13.]), (9, 2, False): array([3., 8.]), (18, 2, False): array([ 6., 40.]), (18, 10, False): array([ 37., 144.]), (15, 6, True): array([3., 3.]), (12, 9, False): array([15., 33.]), (16, 6, False): array([ 9., 31.]), (17, 8, False): array([11., 25.]), (12, 6, False): array([ 7., 36.]), (20, 6, False): array([51., 12.]), (12, 10, False): array([ 41., 172.]), (20, 10, False): array([223.,  53.]), (9, 10, False): array([17., 58.]), (19, 10, False): array([150.,  32.]), (14, 4, False): array([ 8., 36.]), (14, 10, False): array([ 35., 155.]), (16, 10, False): array([ 45., 168.]), (5, 6, False): array([0., 3.]), (7, 8, False): array([1., 5.]), (19, 10, True): array([21.,  5.]), (13, 9, False): array([ 6., 33.]), (14, 7, False): array([15., 40.]), (13, 7, False): array([ 7., 22.]), (17, 10, False): array([ 40., 148.]), (19, 5, False): array([41., 10.]), (20, 8, False): array([52., 15.]), (21, 10, True): array([76., 19.]), (21, 4, True): array([14.,  0.]), (11, 6, False): array([ 4., 14.]), (15, 6, False): array([ 9., 40.]), (17, 3, False): array([ 7., 33.]), (19, 3, False): array([38.,  5.]), (8, 8, False): array([3., 9.]), (13, 8, False): array([ 5., 31.]), (8, 10, False): array([13., 40.]), (12, 7, False): array([ 5., 32.]), (17, 7, False): array([ 9., 41.]), (19, 7, False): array([31., 13.]), (19, 6, True): array([8., 0.]), (13, 6, False): array([ 8., 38.]), (14, 1, False): array([11., 35.]), (20, 2, False): array([51., 13.]), (5, 9, False): array([2., 6.]), (16, 9, True): array([ 0., 10.]), (18, 9, True): array([4., 4.]), (16, 9, False): array([ 7., 44.]), (14, 5, False): array([ 6., 30.]), (16, 5, False): array([11., 39.]), (17, 5, False): array([ 8., 32.]), (10, 1, False): array([ 6., 15.]), (21, 1, True): array([13.,  2.]), (9, 1, False): array([ 2., 18.]), (15, 1, False): array([12., 34.]), (18, 3, False): array([ 7., 37.]), (14, 6, False): array([10., 34.]), (19, 6, False): array([32., 10.]), (17, 2, False): array([10., 34.]), (20, 7, False): array([55., 12.]), (6, 10, False): array([ 5., 26.]), (20, 3, False): array([59., 13.]), (13, 10, False): array([ 42., 111.]), (19, 2, False): array([40.,  8.]), (21, 2, True): array([15.,  4.]), (20, 1, False): array([54.,  9.]), (11, 10, False): array([13., 72.]), (21, 5, True): array([19.,  6.]), (20, 5, False): array([53.,  9.]), (14, 2, False): array([14., 28.]), (7, 10, False): array([ 8., 30.]), (20, 4, False): array([52., 11.]), (13, 1, False): array([14., 34.]), (5, 1, False): array([0., 5.]), (16, 7, False): array([ 7., 23.]), (18, 8, False): array([ 8., 31.]), (19, 4, False): array([28.,  6.]), (16, 3, False): array([ 7., 40.]), (13, 10, True): array([1., 8.]), (15, 10, False): array([ 42., 137.]), (21, 7, True): array([26.,  6.]), (16, 1, False): array([11., 43.]), (19, 9, True): array([3., 1.]), (6, 2, False): array([1., 6.]), (15, 2, False): array([ 9., 32.]), (6, 1, False): array([2., 3.]), (10, 5, False): array([ 5., 14.]), (15, 5, False): array([10., 41.]), (8, 5, False): array([ 4., 14.]), (15, 3, False): array([ 7., 30.]), (15, 7, False): array([ 7., 35.]), (21, 7, False): array([26.,  2.]), (14, 9, False): array([12., 36.]), (20, 10, True): array([26.,  8.]), (8, 6, False): array([ 2., 11.]), (16, 4, False): array([ 7., 37.]), (21, 10, False): array([78., 19.]), (20, 8, True): array([4., 3.]), (9, 9, False): array([1., 6.]), (11, 7, False): array([ 2., 21.]), (10, 10, False): array([16., 54.]), (12, 3, False): array([ 5., 39.]), (18, 8, True): array([ 2., 12.]), (21, 8, True): array([15.,  5.]), (14, 3, False): array([ 9., 40.]), (8, 2, False): array([5., 7.]), (11, 2, False): array([ 2., 17.]), (19, 9, False): array([27., 12.]), (13, 2, True): array([0., 3.]), (13, 2, False): array([ 8., 40.]), (4, 10, False): array([ 1., 10.]), (6, 3, Fal ...
# , Q defaultdict(<function mc_prediction_q.<locals>.<lambda> at 0x0000028E7AF40840>, {(16, 8, False): array([-0.53846154, -0.82352941]), (18, 7, False): array([ 0.44444444, -0.75      ]), (13, 4, False): array([-0.5       , -0.83333333]), (20, 9, False): array([ 0.71153846, -0.84615385]), (9, 2, False): array([-0.33333333, -0.5       ]), (18, 2, False): array([ 0.33333333, -0.875     ]), (18, 10, False): array([-0.48648649, -0.82638889]), (15, 6, True): array([-1.        ,  0.33333333]), (12, 9, False): array([-0.33333333, -0.57575758]), (16, 6, False): array([ 0.11111111, -0.61290323]), (17, 8, False): array([-0.18181818, -0.76      ]), (12, 6, False): array([-0.14285714, -0.38888889]), (20, 6, False): array([ 0.76470588, -1.        ]), (12, 10, False): array([-0.70731707, -0.5755814 ]), (20, 10, False): array([ 0.31390135, -0.79245283]), (9, 10, False): array([-0.52941176, -0.55172414]), (19, 10, False): array([-0.10666667, -0.84375   ]), (14, 4, False): array([ 0.25      , -0.63888889]), (14, 10, False): array([-0.42857143, -0.6516129 ]), (16, 10, False): array([-0.46666667, -0.67261905]), (5, 6, False): array([ 0., -1.]), (7, 8, False): array([-1. , -0.6]), (19, 10, True): array([-0.04761905, -1.        ]), (13, 9, False): array([-1.        , -0.66666667]), (14, 7, False): array([-0.33333333, -0.25      ]), (13, 7, False): array([-1.        , -0.09090909]), (17, 10, False): array([-0.325     , -0.72297297]), (19, 5, False): array([ 0.65853659, -0.9       ]), (20, 8, False): array([ 0.80769231, -0.73333333]), (21, 10, True): array([ 0.90789474, -0.05263158]), (21, 4, True): array([0.85714286, 0.        ]), (11, 6, False): array([-0.5       ,  0.07142857]), (15, 6, False): array([ 0.33333333, -0.5       ]), (17, 3, False): array([ 0.14285714, -0.45454545]), (19, 3, False): array([ 0.57894737, -0.6       ]), (8, 8, False): array([ 0.33333333, -0.22222222]), (13, 8, False): array([-0.2      , -0.4516129]), (8, 10, False): array([-1. , -0.6]), (12, 7, False): array([-1.   , -0.125]), (17, 7, False): array([-0.33333333, -0.43902439]), (19, 7, False): array([ 0.67741935, -0.69230769]), (19, 6, True): array([0.375, 0.   ]), (13, 6, False): array([-0.5       , -0.47368421]), (14, 1, False): array([-0.81818182, -0.62857143]), (20, 2, False): array([ 0.64705882, -1.        ]), (5, 9, False): array([ 0.        , -0.16666667]), (16, 9, True): array([ 0. , -0.1]), (18, 9, True): array([-1., -1.]), (16, 9, False): array([-1.        , -0.43181818]), (14, 5, False): array([ 0.33333333, -0.4       ]), (16, 5, False): array([-0.45454545, -0.69230769]), (17, 5, False): array([-0.375, -0.625]), (10, 1, False): array([-0.66666667, -0.06666667]), (21, 1, True): array([0.53846154, 0.        ]), (9, 1, False): array([-1.        , -0.66666667]), (15, 1, False): array([-0.66666667, -0.76470588]), (18, 3, False): array([ 0.42857143, -0.91891892]), (14, 6, False): array([ 0.        , -0.55882353]), (19, 6, False): array([ 0.65625, -0.8    ]), (17, 2, False): array([-0.3, -0.5]), (20, 7, False): array([ 0.78181818, -0.83333333]), (6, 10, False): array([-0.6       , -0.61538462]), (20, 3, False): array([ 0.72881356, -1.        ]), (13, 10, False): array([-0.38095238, -0.6036036 ]), (19, 2, False): array([ 0.3 , -0.75]), (21, 2, True): array([ 0.86666667, -0.5       ]), (20, 1, False): array([ 0.12962963, -1.        ]), (11, 10, False): array([-0.07692308, -0.29166667]), (21, 5, True): array([ 0.84210526, -0.33333333]), (20, 5, False): array([ 0.71698113, -0.77777778]), (14, 2, False): array([ 0.28571429, -0.39285714]), (7, 10, False): array([-0.75      , -0.36666667]), (20, 4, False): array([ 0.65384615, -1.        ]), (13, 1, False): array([-0.71428571, -0.64705882]), (5, 1, False): array([ 0. , -0.2]), (16, 7, False): array([-0.71428571, -0.73913043]), (18, 8, False): array([-0.5       , -0.58064516]), (19, 4, False): array([ 0.60714286, -0.66666667]), (16, 3, False): array([-0.42857143, -0.55      ]), (13, 10, True): array([1., 0.]), (15, 10, False):  ...
#  reward_sum defaultdict(<function mc_prediction_q.<locals>.<lambda> at 0x0000028E7ABCBA60>, {(16, 8, False): array([ -7., -28.]), (18, 7, False): array([  4., -36.]), (13, 4, False): array([ -4., -20.]), (20, 9, False): array([ 37., -11.]), (9, 2, False): array([-1., -4.]), (18, 2, False): array([  2., -35.]), (18, 10, False): array([ -18., -119.]), (15, 6, True): array([-3.,  1.]), (12, 9, False): array([ -5., -19.]), (16, 6, False): array([  1., -19.]), (17, 8, False): array([ -2., -19.]), (12, 6, False): array([ -1., -14.]), (20, 6, False): array([ 39., -12.]), (12, 10, False): array([-29., -99.]), (20, 10, False): array([ 70., -42.]), (9, 10, False): array([ -9., -32.]), (19, 10, False): array([-16., -27.]), (14, 4, False): array([  2., -23.]), (14, 10, False): array([ -15., -101.]), (16, 10, False): array([ -21., -113.]), (5, 6, False): array([ 0., -3.]), (7, 8, False): array([-1., -3.]), (19, 10, True): array([-1., -5.]), (13, 9, False): array([ -6., -22.]), (14, 7, False): array([ -5., -10.]), (13, 7, False): array([-7., -2.]), (17, 10, False): array([ -13., -107.]), (19, 5, False): array([27., -9.]), (20, 8, False): array([ 42., -11.]), (21, 10, True): array([69., -1.]), (21, 4, True): array([12.,  0.]), (11, 6, False): array([-2.,  1.]), (15, 6, False): array([  3., -20.]), (17, 3, False): array([  1., -15.]), (19, 3, False): array([22., -3.]), (8, 8, False): array([ 1., -2.]), (13, 8, False): array([ -1., -14.]), (8, 10, False): array([-13., -24.]), (12, 7, False): array([-5., -4.]), (17, 7, False): array([ -3., -18.]), (19, 7, False): array([21., -9.]), (19, 6, True): array([3., 0.]), (13, 6, False): array([ -4., -18.]), (14, 1, False): array([ -9., -22.]), (20, 2, False): array([ 33., -13.]), (5, 9, False): array([ 0., -1.]), (16, 9, True): array([ 0., -1.]), (18, 9, True): array([-4., -4.]), (16, 9, False): array([ -7., -19.]), (14, 5, False): array([  2., -12.]), (16, 5, False): array([ -5., -27.]), (17, 5, False): array([ -3., -20.]), (10, 1, False): array([-4., -1.]), (21, 1, True): array([7., 0.]), (9, 1, False): array([ -2., -12.]), (15, 1, False): array([ -8., -26.]), (18, 3, False): array([  3., -34.]), (14, 6, False): array([  0., -19.]), (19, 6, False): array([21., -8.]), (17, 2, False): array([ -3., -17.]), (20, 7, False): array([ 43., -10.]), (6, 10, False): array([ -3., -16.]), (20, 3, False): array([ 43., -13.]), (13, 10, False): array([-16., -67.]), (19, 2, False): array([12., -6.]), (21, 2, True): array([13., -2.]), (20, 1, False): array([ 7., -9.]), (11, 10, False): array([ -1., -21.]), (21, 5, True): array([16., -2.]), (20, 5, False): array([38., -7.]), (14, 2, False): array([  4., -11.]), (7, 10, False): array([ -6., -11.]), (20, 4, False): array([ 34., -11.]), (13, 1, False): array([-10., -22.]), (5, 1, False): array([ 0., -1.]), (16, 7, False): array([ -5., -17.]), (18, 8, False): array([ -4., -18.]), (19, 4, False): array([17., -4.]), (16, 3, False): array([ -3., -22.]), (13, 10, True): array([1., 0.]), (15, 10, False): array([-30., -93.]), (21, 7, True): array([25.,  4.]), (16, 1, False): array([ -9., -33.]), (19, 9, True): array([1., 1.]), (6, 2, False): array([ 1., -2.]), (15, 2, False): array([  1., -12.]), (6, 1, False): array([-2., -3.]), (10, 5, False): array([-1.,  0.]), (15, 5, False): array([ -8., -29.]), (8, 5, False): array([ 0., -5.]), (15, 3, False): array([ -3., -17.]), (15, 7, False): array([ -1., -19.]), (21, 7, False): array([25., -2.]), (14, 9, False): array([ -4., -18.]), (20, 10, True): array([8., 4.]), (8, 6, False): array([ 0., -8.]), (16, 4, False): array([ -5., -21.]), (21, 10, False): array([ 67., -19.]), (20, 8, True): array([ 4., -1.]), (9, 9, False): array([-1., -2.]), (11, 7, False): array([-2., -4.]), (10, 10, False): array([-10., -21.]), (12, 3, False): array([ -3., -23.]), (18, 8, True): array([2., 0.]), (21, 8, True): array([13., -1.]), (14, 3, False): array([ -5., -19.]), (8, 2, False): array([-3.,  3.]), (11, 2, False): array([ 0., -1.]), (19, 9, False): arr ...

# %% [markdown]
# ### Part 2: MC Control
#
# In this section, you will write your own implementation of constant-$\alpha$ MC control.
#
# Your algorithm has four arguments:
# - `env`: This is an instance of an OpenAI Gym environment.
# - `num_episodes`: This is the number of episodes that are generated through agent-environment interaction.
# - `alpha`: This is the step-size parameter for the update step.
# - `gamma`: This is the discount rate.  It must be a value between 0 and 1, inclusive (default value: `1`).
#
# The algorithm returns as output:
# - `Q`: This is a dictionary (of one-dimensional arrays) where `Q[s][a]` is the estimated action value corresponding to state `s` and action `a`.
# - `policy`: This is a dictionary where `policy[s]` returns the action that the agent chooses after observing state `s`.
#
# (_Feel free to define additional functions to help you to organize your code._)

# %%
def mc_control(env, num_episodes, alpha, gamma=1.0):
    nA = env.action_space.n
    # initialize empty dictionary of arrays
    Q = defaultdict(lambda: np.zeros(nA))
    # loop over episodes
    for i_episode in range(1, num_episodes+1):
        # monitor progress
        if i_episode % 1000 == 0:
            print("\rEpisode {}/{}.".format(i_episode, num_episodes), end="")
            sys.stdout.flush()
        
        ## TODO: complete the function
        
    return policy, Q

# %% [markdown]
# Use the cell below to obtain the estimated optimal policy and action-value function.  Note that you should fill in your own values for the `num_episodes` and `alpha` parameters.

# %%
# obtain the estimated optimal policy and action-value function
policy, Q = mc_control(env, ?, ?)

# %% [markdown]
# Next, we plot the corresponding state-value function.

# %%
# obtain the corresponding state-value function
V = dict((k,np.max(v)) for k, v in Q.items())

# plot the state-value function
plot_blackjack_values(V)

# %% [markdown]
# Finally, we visualize the policy that is estimated to be optimal.

# %%
# plot the policy
plot_policy(policy)

# %% [markdown]
# The **true** optimal policy $\pi_*$ can be found in Figure 5.2 of the [textbook](http://go.udacity.com/rl-textbook) (and appears below).  Compare your final estimate to the optimal policy - how close are you able to get?  If you are not happy with the performance of your algorithm, take the time to tweak the decay rate of $\epsilon$, change the value of $\alpha$, and/or run the algorithm for more episodes to attain better results.
#
# ![True Optimal Policy](images/optimal.png)
